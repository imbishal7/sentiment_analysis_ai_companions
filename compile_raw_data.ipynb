# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import os

# %%
unique_review_class = 'RHo1pe'
date_class = 'bp9Aid'
rating_class = 'iXRFPc'
review_class = 'h3YV2d'

df_columns = ['app', 'date', 'review', 'rating']

# %%
appss = ["replika", "snapchat",'chatgpt', 'googleassistant']

for app_name in appss:

  file_path = f"/content/drive/MyDrive/Study/Spring 24/HON 112/FinalProject/raw/{app_name}/"
  save_path = f"/content/drive/MyDrive/Study/Spring 24/HON 112/FinalProject/data/{app_name}_reviews.csv"
  result = []

  def html_to_csv(file_name):
    full_path = file_path + file_name
    print(f'Now making soup for {file_name}')
    soup = BeautifulSoup(open(full_path), 'html.parser')
    unique_revs = soup.find_all('div', {'class': unique_review_class})

    for i in unique_revs:
      try:
        date = i.find('span', {'class': date_class}).text
      except:
        date = 'NA'
      try:
        rating = i.find('div', {'class': rating_class})['aria-label']
      except:
        rating = 'NA'
      try:
        review = i.find('div', {'class': review_class}).text
      except:
        review = 'NA'

      result.append([app_name, date, review, rating])

  for i in os.listdir(file_path):
    html_to_csv(i)

  df = pd.DataFrame(result, columns = df_columns)
  df['rating'] = df['rating'].apply(lambda x: x.split(' ')[1])

  df.to_csv(save_path)
# Out:
# Now making soup for ai.replika.app_1_stars.html
# Now making soup for ai.replika.app_2_stars.html
# Now making soup for ai.replika.app_3_stars.html
# Now making soup for ai.replika.app_4_stars.html
# Now making soup for ai.replika.app_5_stars.html
# Now making soup for com.snapchat.android_1_stars.html
# Now making soup for com.snapchat.android_2_stars.html
# Now making soup for com.snapchat.android_3_stars.html
# Now making soup for com.snapchat.android_4_stars.html
# Now making soup for com.snapchat.android_5_stars.html
# Now making soup for com.openai.chatgpt_5_stars.html
# Now making soup for com.openai.chatgpt_2_stars.html
# Now making soup for com.openai.chatgpt_3_stars.html
# Now making soup for com.openai.chatgpt_4_stars.html
# Now making soup for com.openai.chatgpt_1_stars.html

# %%
appss = ["replika", "snapchat",'chatgpt', 'googleassistant']

save_path = [f"/content/drive/MyDrive/Study/Spring 24/HON 112/FinalProject/data/{app_name}_reviews.csv" for app_name in appss]

# %%
save_path
# Out:
# ['/content/drive/MyDrive/Study/Spring 24/HON 112/FinalProject/data/replika_reviews.csv',
#  '/content/drive/MyDrive/Study/Spring 24/HON 112/FinalProject/data/snapchat_reviews.csv',
#  '/content/drive/MyDrive/Study/Spring 24/HON 112/FinalProject/data/chatgpt_reviews.csv',
#  '/content/drive/MyDrive/Study/Spring 24/HON 112/FinalProject/data/googleassistant_reviews.csv']

# %%
data = pd.DataFrame()

# %%
for i in save_path:
  df = pd.read_csv(i)
  data = pd.concat([data, df], ignore_index=True)

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data
# Out:
#                     app               date  \
# 0               replika   January 14, 2024
# 1               replika      March 7, 2024
# 2               replika   February 5, 2024
# 3               replika  December 29, 2023
# 4               replika   January 14, 2024
# ...                 ...                ...
# 226527  googleassistant   February 2, 2024
# 226528  googleassistant  December 13, 2023
# 226529  googleassistant  December 19, 2023
# 226530  googleassistant    January 5, 2024
# 226531  googleassistant   January 22, 2024
#
#                                                    review  rating
# 0       There's is still a problem with memory. Worse ...       1
# 1       I only wish I could give this app no stars. I'...       1
# 2       I was curious about AI, this app has alot of w...       1
# 3       Feels like any other chatbot and still can't g...       1
# 4       MORE FRUSTRATING THAN FUN. Almost level 80. Wh...       1
# ...

# %%
data[(data['rating'] == 2) | (data['rating'] == 1) | (data['rating'] == 3)].count()
# Out:
# app       108019
# date      108019
# review    108017
# rating    108019
# dtype: int64

# %%
data['rev_length'] = data['review'].apply(lambda x: len(str(x).split(' ')))

# %%
data
# Out:
#                     app               date  \
# 0               replika   January 14, 2024
# 1               replika      March 7, 2024
# 2               replika   February 5, 2024
# 3               replika  December 29, 2023
# 4               replika   January 14, 2024
# ...                 ...                ...
# 226527  googleassistant   February 2, 2024
# 226528  googleassistant  December 13, 2023
# 226529  googleassistant  December 19, 2023
# 226530  googleassistant    January 5, 2024
# 226531  googleassistant   January 22, 2024
#
#                                                    review  rating  rev_length
# 0       There's is still a problem with memory. Worse ...       1          71
# 1       I only wish I could give this app no stars. I'...       1          97
# 2       I was curious about AI, this app has alot of w...       1          78
# 3       Feels like any other chatbot and still can't g...       1          97
# ...

# %%
data['feedback'] = data['rating'].apply(lambda x: 'positive' if x in[4,5] else 'negative')

# %%
data
# Out:
#                     app               date  \
# 0               replika   January 14, 2024
# 1               replika      March 7, 2024
# 2               replika   February 5, 2024
# 3               replika  December 29, 2023
# 4               replika   January 14, 2024
# ...                 ...                ...
# 226527  googleassistant   February 2, 2024
# 226528  googleassistant  December 13, 2023
# 226529  googleassistant  December 19, 2023
# 226530  googleassistant    January 5, 2024
# 226531  googleassistant   January 22, 2024
#
#                                                    review  rating  rev_length  \
# 0       There's is still a problem with memory. Worse ...       1          71
# 1       I only wish I could give this app no stars. I'...       1          97
# 2       I was curious about AI, this app has alot of w...       1          78
# 3       Feels like any other chatbot and still can't g...       1          97
# ...

# %%
data['rev_length'].mean()
# Out:
# 31.372596366076316

# %%
data.to_csv("/content/drive/MyDrive/Study/Spring 24/HON 112/FinalProject/data/reviews.csv")
